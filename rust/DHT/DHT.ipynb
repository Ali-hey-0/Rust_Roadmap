# %%
def pos(k):
    chars = list(k)
    s = 0
    for c in chars:
        s += ord(c)
        
    s = s % 100
    return s

pos("Ali")
# Out:
# 78

# %%
pos("Reza")
# Out:
# 2

# %%
pos("Maryam")
# Out:
# 15

# %%
pos("Sarah")
# Out:
# 95

# %%
pos("Ail")
# Out:
# 78

# %%
echo -n Ali | md5sum

# 7a9b46ab6d983a85dd4d9a1aa64a3945  -

# %%
echo -n Ail | md5sum

# c4a2c2078019464e402883f603a2b70f  -

# %%
# if contents be the in same address , we can use hashing functions like md5 to generate unique addresses and if still be same we can do these :

# 1.First Empty Next Cell 
# 2.first Empty next exponential Cell
# 3.Linkid List Storage

# %%
import math 

print(math.pow(256,4)) # 4 byte address space

print(math.pow(254,4)) # 4 byte address space

print(1*4_000_000_000*5) #time to scan all addresses at 5gb/s
# Out:
# 4294967296.0
# 4162314256.0
# 20000000000

# %%
# Explain dht alghorithms with example

# %%
# Explain chord dht alghorithm with example
# Explain kademlia dht alghorithm with example

# %%
math.log2(4_000_000_000)

# With 32 bit address space we can have 4 billion addresses and with log2 algorithm we can find each address in maximum 32 steps
# Out:
# 31.897352853986263
